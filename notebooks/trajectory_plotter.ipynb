# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]

# %%
# Sample dataset with three columns
dataset = np.array([
[1.69372,2.09526,-0.0204977,0.0143124],
[1.67322,2.10957,-0.0204706,0.0143509],
[1.65275,2.12392,-0.0201277,0.0148283],
[1.63262,2.13875,-0.0202071,0.0147198],
[1.61242,2.15347,-0.020232,0.0146856],
[1.59219,2.16815,-0.0200823,0.0148895],
[1.5721,2.18304,-0.0201009,0.0148647],
[1.552,2.19791,-0.0201399,0.0148115],
[1.53186,2.21272,-0.0200274,0.0149635],
[1.51184,2.22768,-0.0200535,0.0149284],
[1.49178,2.24261,-0.0200867,0.0148838],
[1.47169,2.25749,-0.0200825,0.0148893],
[1.45161,2.27238,-0.0200356,0.0149523],
[1.43158,2.28734,-0.0200459,0.0149387],
[1.41153,2.30227,-0.0200521,0.0149302],
[1.39148,2.3172,-0.0200223,0.0149702],
[1.37146,2.33217,-0.0200236,0.0149685],
[1.35143,2.34714,-0.0200364,0.0149513],
[1.3314,2.36209,-0.0200369,0.0149508],
[1.31136,2.37704,-0.0200073,0.01499],
[1.29135,2.39203,-1.92426e-08,5.97233e-08]
])

# Separate columns into individual arrays
column1 = dataset[:, 0]
column2 = dataset[:, 1]
column3 = dataset[:, 2]
column4 = dataset[:, 3]

x = column1
y = column2
dx = column3
dy = column4
xplt = []
yplt = []

# %%
xplt = []
yplt = []

plt.figure(figsize=(6, 4))  # Adjust the figure size if needed




for i in range(0,len(x),1):
    plt.arrow(x[i], y[i], dx[i]*5, dy[i]*5, width=0.001, head_width=0.002, head_length=0.005, length_includes_head=True)
    xplt.append(x[i])
    yplt.append(y[i])
plt.scatter(xplt, yplt)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Plot with Turned Arrows')
plt.grid(True)
plt.show()

# %%
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('X-Y Graph')
plt.grid(True)
plt.show()

# %%
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('X-Y Graph')
plt.grid(True)
plt.show()
